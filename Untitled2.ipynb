# %% [markdown]
# 1. Conceito de Variáveis ​​em Python

# %%
idade = 20
nome = "Ana"
altura = 1.65

# %% [markdown]
# 2. Tipagem Dinâmica e Orientação a Objetos

# %% [markdown]
# Python é uma linguagem orientada a objetos, na qual tudo é tratado como um objeto, incluindo números, textos e estruturas de dados.
#
# Cada variável referencial de um objeto que possui:
#
# Um tipo
# Um valor
# Métodos associados
# Essa abordagem é fundamental para a compreensão futura de conceitos mais avançados, como estruturas de dados, bibliotecas científicas e frameworks de Machine Learning.

# %% [markdown]
# 3. Tipos de Dados Básicos

# %% [markdown]
# Os tipos de dados básicos são essenciais para a construção de qualquer programa e formam a base para aplicações em Ciência de Dados e Machine Learning.

# %% [markdown]
# 3.1 Inteiros (int)

# %%
quantidade = 10
ano = 2025

# %% [markdown]
# 3.2 Números de Ponto Flutuante (float)

# %%
preco = 19.90
media = 7.5

# %% [markdown]
# 3.3 Texto (str)

# %%
mensagem = "Python é incrível"
nome = 'Carlos'

# %%
frase = "Aprender Python não é difícil"

# %% [markdown]
# 3.4 Valores Booleanos (bool)

# %% [markdown]
# O tipo booleano representa valores lógicos e possui apenas dois estados possíveis:
#
# True(verdadeiro)
# False(falso)

# %%
aprovado = True
maior_de_idade = False

# %% [markdown]
# 4. Verificação de Tipos com a Função type()

# %%
idade = 20
print(type(idade))

preco = 19.90
print(type(preco))

mensagem = "Olá, Python"
print(type(mensagem))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# 5. Entrada de dados do usuário

# %%
nome = input("Digite seu nome: ")
print("Bem-vindo,", nome)
# Out:
# Digite seu nome: Janderson
# Bem-vindo, Janderson

# %% [markdown]
# 6. Conversão de Tipos (Casting)

# %%
idade = int(input("Digite sua idade: "))
altura = float(input("Digite sua altura: "))
# Out:
# Digite sua idade: 30
# Digite sua altura: 1.70

# %% [markdown]
# 7. Operadores Básicos

# %% [markdown]
# Python oferece operadores aritméticos para realização de cálculos matemáticos.
#
# Operador	Descrição
# +	Adição
# -	Subentende
# *	Multiplicação
# /	Divisão
# //	Divisão inteira
# %	Resto da por
# **	Potência

# %%
a = 10
b = 3

print(a + b)
print(a * b)
print(a ** b)
# Out:
# 13
# 30
# 1000

# %% [markdown]
# 8. Boas Práticas no Uso de Variáveis

# %% [markdown]
# Desde os primeiros programas, é importante adotar boas práticas de programação:
#
# Utilização nomes claros e descritivos
# Evitar acentos e espaços
# Usar letras minúsculas e _(snake_case

# %%
media_final = 8.2
total_alunos = 35

# %% [markdown]
# 9. Exercícios Propostos

# %% [markdown]
# Crie um programa que solicite o nome e a idade do usuário e exiba uma mensagem personalizada.
#
# Leia dois números informados pelo usuário e exiba a soma.
#
# Calcule a média de três notas digitadas pelo usuário.
#
# Crie uma variável booleana que indique se o aluno foi aprovado (nota maior ou igual a 6)
