# %% [markdown]
# # 📊 Python Avançado - Visualizações e Projetos
#
# Exemplos com gráficos, análise de dados e API.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0,10)
y = x**2
plt.plot(x,y)
plt.title('y = x²')
plt.show()

# %%
dados={'Nome':['Ana','Bruno','Carlos'],'Salario':[3000,5000,4000]}
df=pd.DataFrame(dados)
print(df)
# Out:
#      Nome  Salario
# 0     Ana     3000
# 1   Bruno     5000
# 2  Carlos     4000

# %%
plt.bar(df['Nome'],df['Salario'])
plt.title('Salários')
plt.show()

# %%
import requests
r=requests.get('https://api.github.com')
print(r.status_code)
# Out:
# 200

# %%
print('Média:',df['Salario'].mean())
# Out:
# Média: 4000.0
