# %% [markdown]
# 1. O que são Listas

# %% [markdown]
# Em Python, listas são estruturas de dados utilizadas para armazenar coleções ordenadas de valores. Eles são semelhantes aos vetores ou arrays de outras linguagens de programação, porém com maior flexibilidade.
#
# Uma lista pode:
#
# Armazenar diferentes tipos de dados (números, textos, booleanos, etc.)
# Conte quantos elementos são necessários
# Ser percorrido (iterado) facilmente
# Ter seus valores alterados durante a execução do programa
# Listas são amplamente utilizadas em Ciência de Dados e Machine Learning para armazenar conjuntos de dados, resultados intermediários e coleções de valores.

# %% [markdown]
# 2. Criação de Listas

# %% [markdown]
# Uma lista é criada utilizando colchetes [], com os elementos separados por vírgula.

# %%
numbers = [1, 2, 3]
names = ["Ana", "Carlos", "Maria"]

# %%
numbers = []
strings = []

# %% [markdown]
# 3. Tipos de Dados em Listas

# %%
mixed_list = [1, "Python", 3.14, True]

# %% [markdown]
# 4. Acesso aos Elementos de uma Lista

# %% [markdown]
# Os elementos de uma lista são acessados ​​por meio de índices, que começam em zero.

# %%
names = ["Ana", "Carlos", "Maria"]

print(names[0])  # Ana
print(names[1])  # Carlos
print(names[2])  # Maria
# Out:
# Ana
# Carlos
# Maria

# %% [markdown]
# Índice ≠
# Tentar acessar um índice que não existe gera um erro (exceção):

# %%
print(names[3])  # IndexError
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_2966/995139452.py in <cell line: 0>()
# ----> 1 print(names[3])  # IndexError
#
# IndexError: list index out of range

# %% [markdown]
# 5. Adicionando elementos com o método append()

# %% [markdown]
# O método append()permite adicionar um novo elemento ao final da lista.

# %%
numbers = []

numbers.append(1)
numbers.append(2)
numbers.append(3)

print(numbers)
# Out:
# [1, 2, 3]

# %% [markdown]
# Da mesma forma, podemos adicionar textos a uma lista de strings:

# %%
strings = []

strings.append("hello")
strings.append("world")

print(strings)
# Out:
# ['hello', 'world']

# %% [markdown]
# 6. Importância das Listas no Contexto do Projeto

# %% [markdown]
# No contexto do projeto Introdução à Programação em Python e Fundamentos de Machine Learning, as listas são fundamentais para:
#
# Armazenar conjuntos de dados
# Representar amostras e variáveis
# Preparar dados para bibliotecas como NumPy e Pandas
# Resultados manipulativos de modelos e algoritmos
# O domínio de listas é um passo essencial antes do estudo de estruturas mais avançadas.

# %% [markdown]
# 7. Exercício Proposto

# %% [markdown]
# Realize as seguintes tarefas:
#
# Crie uma lista vazia chamada numberse adicione os números 1, 2 e 3 utilizando o métodoappend()
#
# Crie uma lista vazia chamada stringse adicione as palavras "hello" e "world"
#
# Dada a lista abaixo, atribua à variável second_nameo segundo nome da lista

# %%
names = ["Ana", "Carlos", "Maria"]

# %% [markdown]
# Resultado (exemplo)

# %%
numbers = []
strings = []

numbers.append(1)
numbers.append(2)
numbers.append(3)

strings.append("hello")
strings.append("world")

names = ["Ana", "Carlos", "Maria"]
second_name = names[1]

print(numbers)
print(strings)
print(second_name)
# Out:
# [1, 2, 3]
# ['hello', 'world']
# Carlos

# %% [markdown]
# 8. Conexão com Próximos Conteúdos

# %% [markdown]
# O estudo de listas prepara o estudante para compreender:
#
# Estruturas de reprodução ( for, while)
#
# Estruturas de dados avançadas
#
# Manipulação de dados com NumPy e Pandas
#
# Representação de conjuntos de dados em Machine Learning
